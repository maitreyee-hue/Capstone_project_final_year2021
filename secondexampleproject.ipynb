# %%
import pandas as pd
import numpy as np
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer

pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)
# %matplotlib inline

# %%
with open('demop.csv') as f:
    df = pd.read_csv(f)
f.close()

# %%
df
# Out:
#     Tweet                                              Subjectivity
# 0       0                                             Pronouns suck
# 1       1                                          ?? Twitter sucks
# 2       2         Another government stimulus package is not in ...
# 3       3                      Tesla solar panels are $1.49/Watt \n
# 4       4           While in orbit, astronauts and performed a h...
# 5       5         Impressive Tianwen-1 Mars rover mission launch...
# 6       6                 Das baby kann noch keinen löffel benutzen
# 7       7                     You don’t have a soul, you are a soul
# 8       8                                         2 minutes later …
# 9       9                                               Coming soon
# 10     10                Where are the memes? Send in … the memes …
# 11     11                                         not good this is!
# 12     12  This is a very good site. I will recommend it to others.

# %%
import pandas as pd
import nltk

df['tokenized_sents'] = df.apply(lambda row: nltk.word_tokenize(row['Subjectivity']), axis=1)

# %%
df
# Out:
#     Tweet                                              Subjectivity  \
# 0       0                                             Pronouns suck
# 1       1                                          ?? Twitter sucks
# 2       2         Another government stimulus package is not in ...
# 3       3                      Tesla solar panels are $1.49/Watt \n
# 4       4           While in orbit, astronauts and performed a h...
# 5       5         Impressive Tianwen-1 Mars rover mission launch...
# 6       6                 Das baby kann noch keinen löffel benutzen
# 7       7                     You don’t have a soul, you are a soul
# 8       8                                         2 minutes later …
# 9       9                                               Coming soon
# 10     10                Where are the memes? Send in … the memes …
# 11     11                                         not good this is!
# 12     12  This is a very good site. I will recommend it to others.
#
#                                                               tokenized_sents
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]

# %%
def check_find_punctuations(text): 
    
    # regular expression containing 
    # all punctuation 
    result = re.findall(r'[!"\$%&\'()*+,\-.\/:;=#@?\[\\\]^_`{|}~]*',  
                        text) 
      
    # form a string 
    string = "".join(result) 
      
    # list of strings return 
    return list(string) 
    
# creating new column name 
# as a punctuation_used and  
# applying user defined function 
# on each rows of Comments column 
df['punctuation_used'] = df['Subjectivity'].apply( 
                         lambda x : check_find_punctuations(x) 
                         )


  
# show the Dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1c76d162ba0b> in <module>
#      17 # on each rows of Comments column
#      18 df['punctuation_used'] = df['Subjectivity'].apply(
# ---> 19                          lambda x : check_find_punctuations(x)
#      20                          )
#      21
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-16-1c76d162ba0b> in <lambda>(x)
#      17 # on each rows of Comments column
#      18 df['punctuation_used'] = df['Subjectivity'].apply(
# ---> 19                          lambda x : check_find_punctuations(x)
#      20                          )
#      21
#
# <ipython-input-16-1c76d162ba0b> in check_find_punctuations(text)
#       3     # regular expression containing
#       4     # all punctuation
# ----> 5     result = re.findall(r'[!"\$%&\'()*+,\-.\/:;=#@?\[\\\]^_`{|}~]*',
#       6                         text)
#       7
#
# NameError: name 're' is not defined

# %%
df
# Out:
#     Tweet                                              Subjectivity  \
# 0       0                                             Pronouns suck
# 1       1                                          ?? Twitter sucks
# 2       2         Another government stimulus package is not in ...
# 3       3                      Tesla solar panels are $1.49/Watt \n
# 4       4           While in orbit, astronauts and performed a h...
# 5       5         Impressive Tianwen-1 Mars rover mission launch...
# 6       6                 Das baby kann noch keinen löffel benutzen
# 7       7                     You don’t have a soul, you are a soul
# 8       8                                         2 minutes later …
# 9       9                                               Coming soon
# 10     10                Where are the memes? Send in … the memes …
# 11     11                                         not good this is!
# 12     12  This is a very good site. I will recommend it to others.
#
#                                                               tokenized_sents
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df["punctuation_removed"] = df['Subjectivity'].apply(remove_punctuations)
df
# Out:
#     Tweet                                              Subjectivity  \
# 0       0                                             Pronouns suck
# 1       1                                          ?? Twitter sucks
# 2       2         Another government stimulus package is not in ...
# 3       3                      Tesla solar panels are $1.49/Watt \n
# 4       4           While in orbit, astronauts and performed a h...
# 5       5         Impressive Tianwen-1 Mars rover mission launch...
# 6       6                 Das baby kann noch keinen löffel benutzen
# 7       7                     You don’t have a soul, you are a soul
# 8       8                                         2 minutes later …
# 9       9                                               Coming soon
# 10     10                Where are the memes? Send in … the memes …
# 11     11                                         not good this is!
# 12     12  This is a very good site. I will recommend it to others.
#
#                                                               tokenized_sents  \
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]
#
#                                        punctuation_removed
# 0                                            Pronouns suck
# 1                                            Twitter sucks
# 2           Another government stimulus package is not in
# 3                         Tesla solar panels are 149Watt n
# 4              While in orbit astronauts and performed a h
# 5            Impressive Tianwen1 Mars rover mission launch
# 6                Das baby kann noch keinen löffel benutzen
# 7                     You don’t have a soul you are a soul
# 8                                        2 minutes later …
# 9                                              Coming soon
# 10               Where are the memes Send in … the memes …
# 11                                        not good this is
# 12  This is a very good site I will recommend it to others

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

#STOP_WORDS.remove("not")

print(len(STOP_WORDS))
print(STOP_WORDS)
df['stopword_remove'] = df['punctuation_removed'].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOP_WORDS)]))
df
# Out:
# 312
# {'been', 'may', 'done', 'in', 'go', "'re", 'besides', 'each', 'say', 'per', 'afterwards', 'thru', 'have', 'she', 'will', 'beforehand', 'various', 'elsewhere', 'any', 'somehow', 'along', 'one', 'only', 'whatever', 'he', 'ca', 'really', 'when', 'seem', 'the', 'so', 'their', 'should', 'therein', 'already', 'take', 'back', 'everywhere', 'they', 'anywhere', 'between', 'anything', 'thence', 'therefore', 'whither', 'made', 'with', 'whom', 'alone', 'others', 'who', 'other', 'up', 'becomes', 'get', 'own', 'whereby', 'was', 'fifty', 'thereby', 'forty', 'whereupon', 'these', "'ve", 'above', 'of', "'m", 'while', 'via', 'ten', 'through', 'either', 're', 'but', 'to', 'perhaps', 'serious', 'although', 'together', 'however', 'hereupon', 'cannot', 'would', 'else', 'top', 'many', 'did', 'am', 'three', 'which', 'could', 'otherwise', 'whereas', 'nevertheless', 'hers', 'full', 'down', 'some', 'moreover', 'among', 'them', 'those', 'somewhere', 'upon', 'several', 'beyond', 'much', 'due', 'then', 'yet', 'our', 'used', 'seemed', 'behind', 'two', 'even', 'herself', 'show', 'his', 'were', 'too', 'what', 'nor', 'nine', 'everyone', 'also', 'become', 'whence', 'once', 'by', 'against', 'never', 'my', 'himself', 'see', 'anyhow', 'toward', 'namely', 'an', 'mine', 'yourself', 'sometimes', 'twenty', 'whereafter', 'from', 'ourselves', 'amount', 'hundred', 'using', 'across', 'eleven', 'most', 'because', 'hereafter', 'give', 'thereafter', 'seeming', 'very', 'both', 'twelve', 'four', 'that', 'indeed', 'six', 'anyone', 'few', 'yours', 'her', 'are', 'anyway', 'it', 'every', "'ll", 'whenever', 'call', 'often', 'becoming', 'fifteen', 'hereby', 'bottom', 'onto', 'a', 'name', 'part', 'might', 'throughout', 'its', 'everything', 'towards', 'how', 'if', 'into', 'sixty', 'meanwhile', 'before', 'around', 'off', 'unless', 'eight', 'more', 'had', 'always', 'empty', 'except', 'being', 'enough', 'myself', 'me', 'about', 'ours', 'latterly', 'within', 'him', 'latter', 'still', 'we', 'nobody', 'for', 'your', 'least', 'former', 'until', 'be', 'why', 'wherever', 'since', 'at', 'on', 'make', 'wherein', 'again', 'thereupon', 'another', 'out', 'first', 'doing', 'has', 'further', 'without', 'us', 'mostly', 'ever', 'under', 'someone', 'side', 'below', 'front', 'do', 'quite', 'almost', 'does', 'whoever', 'less', 'nothing', 'though', 'must', 'formerly', 'just', 'next', 'third', 'all', 'hence', 'this', 'whether', 'last', 'none', 'well', 'there', 'same', 'regarding', 'noone', 'over', "'d", 'five', 'nowhere', "n't", "'s", 'rather', 'now', 'no', 'sometime', 'something', 'put', 'you', 'whose', 'after', 'itself', 'not', 'yourselves', 'seems', 'i', 'keep', 'is', 'please', 'can', 'themselves', 'and', 'than', 'or', 'neither', 'thus', 'during', 'herein', 'became', 'move', 'amongst', 'such', 'whole', 'as', 'beside', 'where', 'here'}
#     Tweet                                              Subjectivity  \
# 0       0                                             Pronouns suck
# 1       1                                          ?? Twitter sucks
# 2       2         Another government stimulus package is not in ...
# 3       3                      Tesla solar panels are $1.49/Watt \n
# 4       4           While in orbit, astronauts and performed a h...
# 5       5         Impressive Tianwen-1 Mars rover mission launch...
# 6       6                 Das baby kann noch keinen löffel benutzen
# 7       7                     You don’t have a soul, you are a soul
# 8       8                                         2 minutes later …
# 9       9                                               Coming soon
# 10     10                Where are the memes? Send in … the memes …
# 11     11                                         not good this is!
# 12     12  This is a very good site. I will recommend it to others.
#
#                                                               tokenized_sents  \
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]
#
#                                        punctuation_removed  \
# 0                                            Pronouns suck
# 1                                            Twitter sucks
# 2           Another government stimulus package is not in
# 3                         Tesla solar panels are 149Watt n
# 4              While in orbit astronauts and performed a h
# 5            Impressive Tianwen1 Mars rover mission launch
# 6                Das baby kann noch keinen löffel benutzen
# 7                     You don’t have a soul you are a soul
# 8                                        2 minutes later …
# 9                                              Coming soon
# 10               Where are the memes Send in … the memes …
# 11                                        not good this is
# 12  This is a very good site I will recommend it to others
#
#                                   stopword_remove
# 0                                   Pronouns suck
# 1                                   Twitter sucks
# 2             Another government stimulus package
# 3                    Tesla solar panels 149Watt n
# 4              While orbit astronauts performed h
# 5   Impressive Tianwen1 Mars rover mission launch
# 6       Das baby kann noch keinen löffel benutzen
# 7                             You don’t soul soul
# 8                               2 minutes later …
# 9                                     Coming soon
# 10                     Where memes Send … memes …
# 11                                           good
# 12                     This good site I recommend

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
from textblob import TextBlob
def getTextSubjectivity(stopword_remove):
    return TextBlob(stopword_remove).sentiment.subjectivity

def getTextPolarity(stopword_remove):
    return TextBlob(stopword_remove).sentiment.polarity

# %%
df['Subjectivity'] = df['stopword_remove'].apply(getTextSubjectivity)
df['Polarity'] = df['stopword_remove'].apply(getTextPolarity)

# %%
df.head(13)
# Out:
#     Tweet  Subjectivity  \
# 0       0           0.0
# 1       1           0.3
# 2       2           0.0
# 3       3           0.0
# 4       4           0.0
# 5       5           1.0
# 6       6           0.0
# 7       7           0.0
# 8       8           0.0
# 9       9           0.0
# 10     10           0.0
# 11     11           0.6
# 12     12           0.6
#
#                                                               tokenized_sents  \
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]
#
#                                        punctuation_removed  \
# 0                                            Pronouns suck
# 1                                            Twitter sucks
# 2           Another government stimulus package is not in
# 3                         Tesla solar panels are 149Watt n
# 4              While in orbit astronauts and performed a h
# 5            Impressive Tianwen1 Mars rover mission launch
# 6                Das baby kann noch keinen löffel benutzen
# 7                     You don’t have a soul you are a soul
# 8                                        2 minutes later …
# 9                                              Coming soon
# 10               Where are the memes Send in … the memes …
# 11                                        not good this is
# 12  This is a very good site I will recommend it to others
#
#                                   stopword_remove  Polarity
# 0                                   Pronouns suck       0.0
# 1                                   Twitter sucks      -0.3
# 2             Another government stimulus package       0.0
# 3                    Tesla solar panels 149Watt n       0.0
# 4              While orbit astronauts performed h       0.0
# 5   Impressive Tianwen1 Mars rover mission launch       1.0
# 6       Das baby kann noch keinen löffel benutzen       0.0
# 7                             You don’t soul soul       0.0
# 8                               2 minutes later …       0.0
# 9                                     Coming soon       0.0
# 10                     Where memes Send … memes …       0.0
# 11                                           good       0.7
# 12                     This good site I recommend       0.7

# %%
def getTextAnalysis(a):
    if a < 0:
        return "Negative"
    elif a == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
df['Score'] = df['Polarity'].apply(getTextAnalysis)

# %%
df.head(14)
# Out:
#     Tweet  Subjectivity  \
# 0       0           0.0
# 1       1           0.3
# 2       2           0.0
# 3       3           0.0
# 4       4           0.0
# 5       5           1.0
# 6       6           0.0
# 7       7           0.0
# 8       8           0.0
# 9       9           0.0
# 10     10           0.0
# 11     11           0.6
# 12     12           0.6
#
#                                                               tokenized_sents  \
# 0                                                            [Pronouns, suck]
# 1                                                      [?, ?, Twitter, sucks]
# 2                  [Another, government, stimulus, package, is, not, in, ...]
# 3                               [Tesla, solar, panels, are, $, 1.49/Watt, \n]
# 4                [While, in, orbit, ,, astronauts, and, performed, a, h, ...]
# 5                  [Impressive, Tianwen-1, Mars, rover, mission, launch, ...]
# 6                           [Das, baby, kann, noch, keinen, löffel, benutzen]
# 7                       [You, don, ’, t, have, a, soul, ,, you, are, a, soul]
# 8                                                      [2, minutes, later, …]
# 9                                                              [Coming, soon]
# 10                    [Where, are, the, memes, ?, Send, in, …, the, memes, …]
# 11                                                   [not, good, this, is, !]
# 12  [This, is, a, very, good, site, ., I, will, recommend, it, to, others, .]
#
#                                        punctuation_removed  \
# 0                                            Pronouns suck
# 1                                            Twitter sucks
# 2           Another government stimulus package is not in
# 3                         Tesla solar panels are 149Watt n
# 4              While in orbit astronauts and performed a h
# 5            Impressive Tianwen1 Mars rover mission launch
# 6                Das baby kann noch keinen löffel benutzen
# 7                     You don’t have a soul you are a soul
# 8                                        2 minutes later …
# 9                                              Coming soon
# 10               Where are the memes Send in … the memes …
# 11                                        not good this is
# 12  This is a very good site I will recommend it to others
#
#                                   stopword_remove  Polarity     Score
# 0                                   Pronouns suck       0.0   Neutral
# 1                                   Twitter sucks      -0.3  Negative
# 2             Another government stimulus package       0.0   Neutral
# 3                    Tesla solar panels 149Watt n       0.0   Neutral
# 4              While orbit astronauts performed h       0.0   Neutral
# 5   Impressive Tianwen1 Mars rover mission launch       1.0  Positive
# 6       Das baby kann noch keinen löffel benutzen       0.0   Neutral
# 7                             You don’t soul soul       0.0   Neutral
# 8                               2 minutes later …       0.0   Neutral
# 9                                     Coming soon       0.0   Neutral
# 10                     Where memes Send … memes …       0.0   Neutral
# 11                                           good       0.7  Positive
# 12                     This good site I recommend       0.7  Positive

# %%
positive = df[df['Score'] == 'Positive']

print(str(positive.shape[0]/(df.shape[0])*100) + " % of positive tweets")
# Out:
# 23.076923076923077 % of positive tweets

# %%
labels = df.groupby('Score').count().index.values

values = df.groupby('Score').size().values

plt.bar(labels, values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-411029eae154> in <module>
#       3 values = df.groupby('Score').size().values
#       4
# ----> 5 plt.bar(labels, values)
#
# NameError: name 'plt' is not defined

# %%
for index, row in df.iterrows():
    if row['Score'] == 'Positive':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="green")
    elif row['Score'] == 'Negative':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="red")
    elif row['Score'] == 'Neutral':
        plt.scatter(row['Polarity'], row['Subjectivity'], color="blue")

plt.title('Twitter Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
# add legend
plt.show()

# %%
objective = df[df['Subjectivity'] == 0]

print(str(objective.shape[0]/(df.shape[0])*100) + " % of objective tweets")
# Out:
# 69.23076923076923 % of objective tweets

# %%
X = df.iloc[:, :-2].values
y = df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50)
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-6affca082033> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 classifier = RandomForestClassifier(n_estimators = 50)
# ----> 3 classifier.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: setting an array element with a sequence.
