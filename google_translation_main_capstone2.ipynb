# %% [markdown]
# Translation/Module 2

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install googletrans==3.1.0a0
# Out:
# ...
#      |████████████████████████████████| 61kB 3.1MB/s
# ...
#      |████████████████████████████████| 1.0MB 6.6MB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 61kB 5.6MB/s
# ...
#      |████████████████████████████████| 71kB 5.8MB/s
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-cp37-none-any.whl size=16368 sha256=2e8987376809e178fd19664f0cb5ea5689da3cf5b4961fa7ba0e212cec383924
#   Stored in directory: /root/.cache/pip/wheels/27/7a/a0/aff3babbb775549ce6813cb8fa7ff3c0848c4dc62c20f8fdac
# Successfully built googletrans
# ...

# %%
from googletrans import Translator

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/pred_data.csv')

# %%
df.values.tolist()[0]
# Out:
# ['News updates:\n\n103 वर्षीय स्वतंत्रता सेनानी बिरदीचंद गोठी ने दी Corona को मात\n\n#hindyug #CovidIndia #COVID19… https://t.co/YFGPOeVR6A']

# %%
inputs = marathi_tweet[0:100]
english_tweets = []

# print outputs

l = len(marathi_tweet) // 100
print(l)
i=0
for _ in range(l+1):
  inputs = marathi_tweet[i:i+100]
  outputs = service.translations().list(source='mr', target='en', q=inputs).execute()
  for input, output in zip(inputs, outputs['translations']):
    english_tweets.append(output['translatedText'])

# %%
translator = Translator()
translatedlist = [translator.translate(tweet[0], dest="en").text for tweet in df.values.tolist()]

# %%
print(translatedlist)
# Out:
# ['News updates:\n\n103-year-old freedom fighter Birdichand Gothi beats Corona\n\n#hindyug #CovidIndia # COVID19… https://t.co/YFGPOeVR6A', 'The prevalence of corona in the country is increasing day by day. Over 1.3 million new rupees in the last four days', "Success to Sharad Pawar's call, first pilot project to produce oxygen will start 'Ha' factory… https://t.co/HHTVy4cFLI", 'All political parties should evict their corporators from their homes and put them to work in their wards.\n\nMCMO @ NCP… https://t.co/giaFycniwK', "Nashik's sports, political and cultural sector hit, three veterans die due to corona\n\nhttps://t.co/PbBH1V5ovW #Nashik #Nashikcorona", 'Ajit Pawar | Ajit Pawar reviews Corona situation, meeting at Vidya Pratishthan, Baramati… https://t.co/CBBQuReG03', 'Corona Updates In India: Corona blast in the country! 3.49 lakh patients registered in 24 hours, 2767 deaths\n\nhttps://t.co/hB5TrG20eq', 'I was shocked to hear that "the number 70 in the cemetery, yesterday\'s dea
# ...

# %%
tweets = pd.DataFrame(translatedlist)

# %%
tweets.to_csv('pred_data1.csv',index=False)
